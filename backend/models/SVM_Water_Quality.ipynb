# %% [markdown]
# # Water Quality Assessment using SVM

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('water_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0        pH      Iron   Nitrate    Chloride           Lead  \
# 0           0  8.332988  0.000083  8.605777  122.799772   3.713298e-52
# 1           1  6.917863  0.000081  3.734167  227.029851   7.849262e-94
# 2           2  5.443762  0.020106  3.816994  230.995630   5.286616e-76
# 3           3  7.955339  0.143988  8.224944  178.129940  3.997118e-176
# 4           4  8.091909  0.002167  9.925788  186.540872  4.171069e-132
#
#        Zinc           Color  Turbidity  Fluoride  ...  Chlorine     Manganese  \
# 0  3.434827       Colorless    0.22683  0.607283  ...  3.708178  2.269945e-15
# 1  1.245317    Faint Yellow    0.19007  0.622874  ...  3.292038  8.024076e-07
# 2  0.528280    Light Yellow    3.19956  0.423423  ...  3.560224  7.007989e-02
# 3  4.027879  Near Colorless    1.66319  0.208454  ...  3.516907  2.468295e-02
# 4  3.807511    Light Yellow    0.04867  0.222912  ...  3.177849  3.296139e-03
#
#    Total Dissolved Solids  Source  Water Temperature  Air Temperature  \
# 0              332.118789     NaN                NaN        43.493324
# 1              284.641984    Lake          15.348981        71.220586
# 2              570.054094   River          11.643467        44.891330
# 3              100.043838  Ground          10.092392        60.843233
# 4              168.075545  Spring          15.249416        69.336671
#
#       Month   Day  Time of Day  Target_Class
# 0   January  29.0          4.0             1
# 1  November  26.0         16.0             1
# 2   January  31.0          8.0             0
# 3     April   1.0         21.0             1
# 4      June  29.0          7.0             1
#
# [5 rows x 24 columns]

# %%
data.tail()
# Out:
#         Unnamed: 0        pH      Iron   Nitrate    Chloride           Lead  \
# 99996        99996  8.818809  0.000075  5.491966         NaN   1.018468e-16
# 99997        99997  7.277367  0.000022  2.878326  126.880370   1.965436e-22
# 99998        99998  7.000954  0.012017  4.157934  165.559327  5.501361e-126
# 99999        99999  8.374296  0.134012  2.631553  148.166082   3.845744e-40
# 100000      100000  7.154356  0.092041  5.656341  212.623606   3.102165e-72
#
#             Zinc         Color  Turbidity  Fluoride  ...  Chlorine  Manganese  \
# 99996   0.054606  Light Yellow    6.18404  1.517286  ...  2.479101   0.006608
# 99997   3.632629     Colorless    2.91402  0.228949  ...  3.315341   0.001116
# 99998   2.162606  Faint Yellow    0.55013  0.275803  ...  3.457473   0.010697
# 99999   0.251668     Colorless    4.06297  0.458973  ...  2.603017   0.000242
# 100000  2.462944     Colorless    0.00355  0.962474  ...  2.907079   0.023063
#
#         Total Dissolved Solids   Source  Water Temperature  Air Temperature  \
# 99996               441.819671    River          20.007815        69.299508
# 99997               308.963907  Aquifer           6.787200        70.198798
# 99998               236.960240     Lake          12.707579        46.856938
# 99999               405.005236     Lake          20.841677        55.109951
# 100000              409.911033     Well           4.789358        33.621950
#
#            Month   Day  Time of Day  Target_Class
# 99996     August   8.0         22.0             0
# 99997    January  27.0         14.0             1
# 99998   December  17.0          1.0             1
# 99999        NaN  11.0          3.0             1
# 100000   January  16.0         22.0             1
#
# [5 rows x 24 columns]

# %%
data = data.drop([cols for cols in data.columns if cols not in ['pH', 'Turbidity', 'Total Dissolved Solids', 'Target_Class']], axis=1)

# %%
data
# Out:
#               pH  Turbidity  Total Dissolved Solids  Target_Class
# 0       8.332988    0.22683              332.118789             1
# 1       6.917863    0.19007              284.641984             1
# 2       5.443762    3.19956              570.054094             0
# 3       7.955339    1.66319              100.043838             1
# 4       8.091909    0.04867              168.075545             1
# ...          ...        ...                     ...           ...
# 99996   8.818809    6.18404              441.819671             0
# 99997   7.277367    2.91402              308.963907             1
# 99998   7.000954    0.55013              236.960240             1
# 99999   8.374296    4.06297              405.005236             1
# 100000  7.154356    0.00355              409.911033             1
#
# [100001 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100001 entries, 0 to 100000
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   pH                      98096 non-null   float64
#  1   Turbidity               99186 non-null   float64
#  2   Total Dissolved Solids  99976 non-null   float64
#  3   Target_Class            100001 non-null  int64
# dtypes: float64(3), int64(1)
# memory usage: 3.1 MB

# %% [markdown]
# ### Handling Missing values

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
data.iloc[:,:3] = imputer.fit_transform(data.iloc[:,:3])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100001 entries, 0 to 100000
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   pH                      100001 non-null  float64
#  1   Turbidity               100001 non-null  float64
#  2   Total Dissolved Solids  100001 non-null  float64
#  3   Target_Class            100001 non-null  int64
# dtypes: float64(3), int64(1)
# memory usage: 3.1 MB

# %%
X = data.iloc[:, :3]
y = data.iloc[:, -1]

# %%
print(X)
print(y)
# Out:
#               pH  Turbidity  Total Dissolved Solids
# 0       8.332988    0.22683              332.118789
# 1       6.917863    0.19007              284.641984
# 2       5.443762    3.19956              570.054094
# 3       7.955339    1.66319              100.043838
# 4       8.091909    0.04867              168.075545
# ...          ...        ...                     ...
# 99996   8.818809    6.18404              441.819671
# 99997   7.277367    2.91402              308.963907
# 99998   7.000954    0.55013              236.960240
# 99999   8.374296    4.06297              405.005236
# 100000  7.154356    0.00355              409.911033
#
# [100001 rows x 3 columns]
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1
#          ..
# 99996     0
# 99997     1
# 99998     1
# 99999     1
# 100000    1
# Name: Target_Class, Length: 100001, dtype: int64

# %% [markdown]
# ### Splitting data into training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42
)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### SMOTE to handle class imbalance in the training set

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %% [markdown]
# ### Train the model

# %%
from sklearn.svm import SVC

svm = SVC(probability=True, random_state=42)
svm.fit(X_train_resampled, y_train_resampled)
# Out:
# SVC(probability=True, random_state=42)

# %% [markdown]
# ### Predict Test result

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

y_pred = svm.predict(X_test)
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("Accuracy:")
print(round(accuracy_score(y_test, y_pred)*100, 2))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      6404
#            1       0.96      0.97      0.97     13597
#
#     accuracy                           0.96     20001
#    macro avg       0.95      0.95      0.95     20001
# weighted avg       0.96      0.96      0.96     20001
#
# Confusion Matrix:
# [[ 5916   488]
#  [  380 13217]]
# Accuracy:
# 95.66

# %%
import pickle

with open('svm_model.pkl', 'wb') as file:
    pickle.dump(svm, file)
